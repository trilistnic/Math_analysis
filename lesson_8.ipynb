# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### 1) Найти и изобразить области определения следующих функций:
# $1)z=\sqrt{y·sin(x)}$
#
# $y·sin(x)>=0=>;
#
# $y>0$ и $sin(x)>0$
#
# $y<0$ и $sin(x)<0$

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
z = (y*np.sin(x))**0.5
# Построение графика
#plt.plot(x, y, z)  # построение графика

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z)
# Out:
# C:\Users\cluster\AppData\Local\Temp/ipykernel_21444/96975648.py:3: RuntimeWarning: invalid value encountered in sqrt
#   z = (y*np.sin(x))**0.5

# %% [markdown]
# $2)z=x+arccos(y)$
#
# $-1<=y<=1$

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
z = x*np.arccos(y)
# Построение графика
#plt.plot(x, y, z)  # построение графика

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z)
# Out:
# C:\Users\cluster\AppData\Local\Temp/ipykernel_21444/566801008.py:3: RuntimeWarning: invalid value encountered in arccos
#   z = x*np.arccos(y)

# %% [markdown]
# ### 2) Вычислить пределы:
# $1)lim_{x→0\\y→0}(x+y)·sin(\frac{1}{x})·cos(\frac{1}{x})=0$
#
# При $x,y\ne0$
#
# Поскольку $x+y$ - бесконечно малая
#
# $sin(\frac{1}{x})$ и $cos(\frac{1}{x})$ - ограниченные

# %% [markdown]
# $2)lim_{x→∞\\y→∞}(\frac{xy}{x^{2}+y^{2}})^{x^{2}}$
#
# $x=rcos\phi, y=rsin\phi, r→∞$
#
# $lim_{r→∞}(\frac{rcos\phi·rsin\phi}{r^{2}cos^{2}\phi+r^{2}sin^{2}\phi})^{r^{2}cos^{2}\phi}=lim_{r→∞}(cos\phi·sin\phi)^{r^{2}cos^{2}\phi}=lim_{r→∞}e^{(cos\phi·sin\phi-1)r^{2}cos^{2}\phi}=0$
#
# Поскольку $cos\phi·sin\phi<1$

# %% [markdown]
# $3)lim_{x→0\\y→0}(x^{2}+y^{2})·sin^{3}(\frac{1}{xy})=0$
#
# При $x,y\ne0$
#
# Поскольку $x^{2}+y^{2}$ - бесконечно малая
#
# $sin^{3}(\frac{1}{xy})$ - ограниченная

# %% [markdown]
# $4)lim_{x→0\\y→0}\frac{x^{2}y^{3}}{x^{2}+y^{2}}$
#
# $x=rcos\phi, y=rsin\phi, r→∞0$
#
# $lim_{r→0}\frac{r^{5}cos^{2}\phi·sin^{3}\phi}{r^{2}(cos^{2}\phi+sin^{2}\phi)}=lim_{r→0}r^{3}cos^{2}\phi·sin^{3}\phi=0$

# %% [markdown]
# ### 3) Найти частные и полное приращения данной функции в данной точке и при данных приращениях аргументов:
# $z=x^{2}y$
#
# $M_{0}(1;2)$
#
# $\Delta x=0,1$
#
# $\Delta y=-0,2$
#
# $x_{0}=1$
#
# $y_{0}=2$
#
# $x_{1}=x_{0}+\Delta x, y_{1}=y_{0}+\Delta y, => M_{1}(1,1;1,8)$
#
# $z(M_{0})=1^{2}·2=2$
#
# $z(x_{0}+\Delta x;y_{0})=1,1^{2}·2=2,42$
#
# $z(x_{0};y_{0}+\Delta y)=1^{2}·1,8=1,8$
#
# $z(M_{1})=1,1^{2}·1,8=2,178$
#
# $\Delta_{x} z=z(x_{0}+\Delta x;y_{0})-z(x_{0};y_{0})=2,42-2=0,42$
#
# $\Delta_{y} z=z(x_{0};y_{0}+\Delta y)-z(x_{0};y_{0})=1,8-2=-0,2$
#
# $\Delta_{x} z+\Delta_{y} z=0,42-0,2=0,22$
#
# $\Delta z=z(x_{0}+\Delta x;y_{0}+\Delta y)-z(x_{0};y_{0})=2,178-2=0,178$
#
# $\Delta z \ne \Delta_{x} z+\Delta_{y}$

# %% [markdown]
# ### 4) Найти частные производные данных функций:
# $1)z=e^{x^{2}+y^{2}}$
#
# $z'_{x}=2x·e^{x^{2}+y^{2}}$
#
# $z'_{y}=2y·e^{x^{2}+y^{2}}$

# %% [markdown]
# $2)u=x^{y}+(xy)^{z}+z^{xy}$
#
# $u'{x}=yx^{y-1}+zx^{z-1}·y^{z}+ln(z)·z^{xy}$
#
# $u'{y}=x^{y}·ln(x)+zy^{z-1}·x^{z}+ln(z)·z^{xy}$
#
# $u'{z}=(xy)^{z}·ln(xy)+z^{xy-1}·xy$

# %% [markdown]
# ### 5) Вычислить приближенно:
# $1)1,04^{2,03}$
#
# $f(x,y)=x^{y}, x=1,04, y=2,03$
#
# $f(x_{0},y_{0})=1^2=1, x_{0}=1, y_{0}=2$
#
# $\Delta x =x-x_{0}=0,04$
#
# $\Delta y =y-y_{0}=0,03$
#
# $f'_{x}=y·x^{y-1}, f'_{y}=x^{y}·ln(x)$
#
# $f'_{x}(1,2)=2·1^{2-1}=2, f'_{y}(1,2)=1^{2}·ln(1)=0$
#
# $df(x_{0},y_{0})=f'_{x}\Delta x+f'_{y}\Delta y=2·0,04+0·0,03=0,08$
#
# $f(x+\Delta x;y+\Delta y)\approx f(x_{0},y_{0})+df(x_{0},y_{0})=1+0,08=1,08$

# %% [markdown]
# $2)\sqrt{(sin^{2}1,55+8e^{0,015})^{5}}$
#
# $f(x,y)=(sin^{2}x+8e^{y})^{\frac{5}{2}}, x=1,55, y=0,015$
#
# $f(x_{0},y_{0})=(sin^{2}1,57+8e^{0})^{\frac{5}{2}}=9^{\frac{5}{2}}=243, x_{0}=1,57, y_{0}=0$
#
# $\Delta x =x-x_{0}=-0,02$
#
# $\Delta y =y-y_{0}=0,0015$
#
# $f'_{x}=\frac{5}{2}·(sin^{2}x+8e^{y})^{\frac{3}{2}}·2sin(x)cos(x)$
#
# $f'_{y}=\frac{5}{2}·(sin^{2}x+8e^{y})^{\frac{3}{2}}·8e^{y}$
#
# $f'_{x}(1,57,0)=\frac{5}{2}·9^{\frac{3}{2}}·2·1·0=0$
#
# $f'_{y}(1,57,0)=\frac{5}{2}·9^{\frac{3}{2}}·8·1=540$
#
# $df(x_{0},y_{0})=f'_{x}\Delta x+f'_{y}\Delta y=0·-0,02+540·0,0015=8,1$
#
# $f(x+\Delta x;y+\Delta y)\approx f(x_{0},y_{0})+df(x_{0},y_{0})=243+8,1=251,1$
